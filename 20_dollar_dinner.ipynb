# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/rambotalabong/Desktop/20 dollar dinner/20_dollar_dinner.csv')

# %%
df.head()
# Out:
#                 establishment                                      gmaps  \
# 0  Tong - Bengali Street Food  https://maps.app.goo.gl/XoPVueJdjUeAR1Td7
# 1                Plaza Ortega  https://maps.app.goo.gl/Nj6sCCojSUrqM9Tn9
# 2          Dave's Hot Chicken  https://maps.app.goo.gl/N1Hzub8vzpG9r8K38
# 3                 S & P Lunch  https://maps.app.goo.gl/2rTVPWBVyAro4ztH6
# 4                Urban Hawker  https://maps.app.goo.gl/tT6UjeWc151mcGmv9
#
#                   latlong                                         story_link  \
# 0  40.7102286,-73.7947312  https://hellgatenyc.com/unforgettable-banglade...
# 1  40.6982505,-73.9226004  https://hellgatenyc.com/20-dinner-terrific-tac...
# 2  40.7657431,-74.0552791  https://hellgatenyc.com/20-dinner-daves-hot-ch...
# 3  40.7411388,-73.9901468  https://hellgatenyc.com/20-dinner-court-street...
# 4  40.7609788,-73.9850856  https://hellgatenyc.com/20-dollar-dinner-urban...
#
# ...

# %%
df[['latitude', 'longitude']] = df['latlong'].str.split(',', expand=True)
df = df.drop(columns=['latlong'])

# %%
df.head()
# Out:
#                 establishment                                      gmaps  \
# 0  Tong - Bengali Street Food  https://maps.app.goo.gl/XoPVueJdjUeAR1Td7
# 1                Plaza Ortega  https://maps.app.goo.gl/Nj6sCCojSUrqM9Tn9
# 2          Dave's Hot Chicken  https://maps.app.goo.gl/N1Hzub8vzpG9r8K38
# 3                 S & P Lunch  https://maps.app.goo.gl/2rTVPWBVyAro4ztH6
# 4                Urban Hawker  https://maps.app.goo.gl/tT6UjeWc151mcGmv9
#
#                                           story_link  \
# 0  https://hellgatenyc.com/unforgettable-banglade...
# 1  https://hellgatenyc.com/20-dinner-terrific-tac...
# 2  https://hellgatenyc.com/20-dinner-daves-hot-ch...
# 3  https://hellgatenyc.com/20-dinner-court-street...
# 4  https://hellgatenyc.com/20-dollar-dinner-urban...
#
#                                  address    borough neighborhood      cuisine  \
# 0  169 Street Station, Jamaica, NY 11432     Queens      Jamaica      Bengali
# ...

# %%
df.to_csv('/Users/rambotalabong/Desktop/20 dollar dinner/20_dollar_dinner_new.csv', index=False)
